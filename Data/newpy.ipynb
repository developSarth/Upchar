# %%
import pandas as pd
import random
cf = pd.read_csv('HospitalData.csv')
cf.loc[
    cf['Type of Hospital/Health facility'].str.contains('unknown', case=False, na=False),
    'Type of Hospital/Health facility'
] = 'Government'
cf.to_csv('HospitalDataFinal.csv', index=False)
